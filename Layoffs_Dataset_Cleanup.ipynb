# %% [markdown]
# # Layoffs Dataset Cleanup

# %%
# Import required libraries

import numpy as np 
import pandas as pd 
import requests
import json
import time

# Import API key
from resources.api_keys import geoapify_key

# %%
# Set path to input dataset
file_path = "Input_Data/layoffs.csv"

# read data from csv
layoffs_unsanitized_dataset = pd.read_csv(file_path)
layoffs_unsanitized_dataset
# Out:
#             company        location        industry  total_laid_off  \
# 0          Airtable     SF Bay Area         Product           237.0
# 1                R3   New York City          Crypto             NaN
# 2        Akili Labs          Boston      Healthcare             NaN
# 3            Google     SF Bay Area        Consumer             NaN
# 4            Evolve          Denver          Travel           175.0
# ...             ...             ...             ...             ...
# 3017        Service     Los Angeles          Travel             NaN
# 3018   HopSkipDrive     Los Angeles  Transportation             8.0
# 3019    Panda Squad     SF Bay Area        Consumer             6.0
# 3020  Tamara Mellon     Los Angeles          Retail            20.0
# 3021       EasyPost  Salt Lake City       Logistics            75.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# 0                    0.27  2023-09-14  Series F  United States        1400.0
# 1                    0.20  2023-09-14  Series A  United States         112.0
# 2                    0.40  2023-09-13  Post-IPO  United States         301.0
# 3                     NaN  2023-09-13  Post-IPO  United States          26.0
# 4                    0.20  2023-09-12  Series F  United States         224.0
# ...                   ...         ...       ...            ...           ...
# 3017                 1.00  2020-03-16      Seed  United States           5.1
# 3018                 0.10  2020-03-13   Unknown  United States          45.0
# 3019                 0.75  2020-03-13      Seed  United States           1.0
# 3020                 0.40  2020-03-12  Series C  United States          90.0
# 3021                  NaN  2020-03-11  Series A  United States          12.0
#
# [3022 rows x 9 columns]

# %%
# Check NaN across the dataset
layoffs_unsanitized_dataset.isna().sum()
# Out:
# company                   0
# location                  0
# industry                  0
# total_laid_off          991
# percentage_laid_off    1050
# date                      0
# stage                     7
# country                   0
# funds_raised            307
# dtype: int64

# %%
# Cleanup the dataset for blank values

#Check if the dataset has 'funds_raised','percentage_laid_off' columns, If yes drop those

if set(['funds_raised','percentage_laid_off']).issubset(layoffs_unsanitized_dataset.columns):

    # Drop funds raised and percentage laid off where the value is blank
    layoffs_unsanitized_dataset = layoffs_unsanitized_dataset.drop(['funds_raised','percentage_laid_off'], axis=1)

# There must be atleast 1 reported layoff in any company in this dataset
layoffs_unsanitized_dataset.total_laid_off = layoffs_unsanitized_dataset.total_laid_off.fillna(1)

# Layoffs should be whole numbers not floats
layoffs_unsanitized_dataset.total_laid_off = layoffs_unsanitized_dataset.total_laid_off.astype(int)

# Company with blank funding stage is set to 'Unknown'
layoffs_unsanitized_dataset.stage = layoffs_unsanitized_dataset.stage.fillna('Unknown')

# Print clean result data
layoffs_unsanitized_dataset.head()
# Out:
#       company       location    industry  total_laid_off        date  \
# 0    Airtable    SF Bay Area     Product             237  2023-09-14
# 1          R3  New York City      Crypto               1  2023-09-14
# 2  Akili Labs         Boston  Healthcare               1  2023-09-13
# 3      Google    SF Bay Area    Consumer               1  2023-09-13
# 4      Evolve         Denver      Travel             175  2023-09-12
#
#       stage        country
# 0  Series F  United States
# 1  Series A  United States
# 2  Post-IPO  United States
# 3  Post-IPO  United States
# 4  Series F  United States

# %%
# Add two new columns latitude and Longitude to be used later for Geoviews
layoffs_unsanitized_dataset["Lat"] = ""
layoffs_unsanitized_dataset["Lon"] = ""

# Define the API parameters
params = {
    "apiKey":geoapify_key,
    "format":"json"
}

# Set the base URL
base_url = "https://api.geoapify.com/v1/geocode/search"

# Build a dictionary that will serve as Cache to not hit API for the same city, country combination
city_coordinates = {}

# %%
# Call GeoApify to get Latitute and Longitute for each city.
# Print a message to follow up the airport search
print("Starting City search")

# Loop through the cities_pd DataFrame and search coordinates for each city
for index, row in layoffs_unsanitized_dataset.iterrows():

    # Get the city's name & add ", Australia" to the string so geoapify finds the correct city
    city = row["location"] + ",",row["country"]

    # Add the current city to the parameters
    params["text"] = f"{city}"

    # Make the API request if city & country combination is not in Cache
    if city not in city_coordinates:
        # API is called as city not found in Cache
        print(f"Coordinates for {city} fetched...")
        try:
            response = requests.get(base_url, params=params)

            # Convert response to JSON
            response = response.json()
            city_coordinates[city] = [response["results"][0]["lat"], response["results"][0]["lon"]]
        except:
            print("City coorodinates not found. Skipping...")
            city_coordinates[city] = ['','']
            pass
    

    # Extract latitude and longitude
    layoffs_unsanitized_dataset.loc[index, "Lat"] = city_coordinates[city][0]
    layoffs_unsanitized_dataset.loc[index, "Lon"] = city_coordinates[city][1]
 

# Display sample data to confirm that the coordinates appear
layoffs_unsanitized_dataset.head()
# Out:
# Starting City search
# Coordinates for ('SF Bay Area,', 'United States') fetched...
# Coordinates for ('New York City,', 'United States') fetched...
# Coordinates for ('Boston,', 'United States') fetched...
# Coordinates for ('Denver,', 'United States') fetched...
# Coordinates for ('Montreal,', 'Canada') fetched...
# Coordinates for ('Berlin,', 'Germany') fetched...
# Coordinates for ('Tallinn,', 'Estonia') fetched...
# Coordinates for ('Amsterdam,', 'Netherlands') fetched...
# Coordinates for ('Charlotte,', 'United States') fetched...
# Coordinates for ('Jakarta,', 'Indonesia') fetched...
# Coordinates for ('Tel Aviv,', 'United States') fetched...
# Coordinates for ('Seattle,', 'United States') fetched...
# Coordinates for ('Belo Horizonte,', 'Brazil') fetched...
# Coordinates for ('Portland,', 'United States') fetched...
# Coordinates for ('Accra,', 'Ghana') fetched...
# Coordinates for ('Bengaluru,', 'India') fetched...
# Coordinates for ('Chicago,', 'United States') fetched...
# Coordinates for ('Brno,', 'Czech Republic') fetched...
# Coordinates for ('Mumbai,', 'India') fetched...
# Coordinates for ('London,', 'United Kingdom') fetched...
# Coordinates for ('Dallas,', 'United States') fetched...
# Coordinates for ('Hong Kong,', 'Hong Kong') fetched...
# Coordinates for ('Los Angeles,', 'United States') fetched...
# Coordinates for ('Nairobi,', 'Kenya') fetched...
# Coordinates for ('Tel Aviv,', 'Israel') fetched...
# Coordinates for ('Miami,', 'United States') fetched...
# Coordinates for ('Kolkata,', 'India') fetched...
# Coordinates for ('Gurugram,', 'India') fetched...
# Coordinates for ('Indianapolis,', 'United States') fetched...
# Coordinates for ('San Diego,', 'United States') fetched...
# Coordinates for ('Santa Barbara,', 'United States') fetched...
# Coordinates for ('Helsinki,', 'Finland') fetched...
# Coordinates for ('Atlanta,', 'United States') fetched...
# Coordinates for ('Sandnes,', 'Norway') fetched...
# Coordinates for ('Beijing,', 'China') fetched...
# Coordinates for ('Singapore,', 'Singapore') fetched...
# Coordinates for ('Minneapolis,', 'United States') fetched...
# Coordinates for ('Milwaukee,', 'United States') fetched...
# Coordinates for ('New Delhi,', 'India') fetched...
# Coordinates for ('Manchester,', 'United Kingdom') fetched...
# Coordinates for ('Lehi,', 'United States') fetched...
# Coordinates for ('Austin,', 'United States') fetched...
# Coordinates for ('Barcelona,', 'Spain') fetched...
# Coordinates for ('Washington D.C.,', 'United States') fetched...
# Coordinates for ('Edinburgh,', 'United Kingdom') fetched...
# Coordinates for ('Toronto,', 'Canada') fetched...
# Coordinates for ('Lagos,', 'Nigeria') fetched...
# Coordinates for ('Melbourne,', 'Australia') fetched...
# Coordinates for ('Columbus,', 'United States') fetched...
# Coordinates for ('Sao Paulo,', 'Brazil') fetched...
# Coordinates for ('Dublin,', 'Ireland') fetched...
# Coordinates for ('Auckland,', 'New Zealand') fetched...
# Coordinates for ('Luxembourg,', 'Luxembourg') fetched...
# Coordinates for ('Salt Lake City,', 'United States') fetched...
# Coordinates for ('Lexington,', 'United States') fetched...
# Coordinates for ('Munich,', 'Germany') fetched...
# Coordinates for ('Stockholm,', 'Sweden') fetched...
# Coordinates for ('Phoenix,', 'United States') fetched...
# Coordinates for ('Cayman Islands,', 'Cayman Islands') fetched...
# Coordinates for ('Chennai,', 'India') fetched...
# Coordinates for ('Tampa Bay,', 'United States') fetched...
# Coordinates for ('Sydney,', 'Australia') fetched...
# Coordinates for ('Raleigh,', 'United States') fetched...
# Coordinates for ('Philadelphia,', 'United States') fetched...
# Coordinates for ('Vancouver,', 'Canada') fetched...
# Coordinates for ('Evansville,', 'United States') fetched...
# Coordinates for ('Nashville,', 'United States') fetched...
# Coordinates for ('St. Louis,', 'United States') fetched...
# Coordinates for ('Sacramento,', 'United States') fetched...
# Coordinates for ('Calgary,', 'Canada') fetched...
# Coordinates for ("Ra'anana,", 'Israel') fetched...
# Coordinates for ('Mexico City,', 'Mexico') fetched...
# Coordinates for ('Montreal,', 'United States') fetched...
# Coordinates for ('Førde,', 'Norway') fetched...
# Coordinates for ('Detroit,', 'United States') fetched...
# Coordinates for ('Boise,', 'United States') fetched...
# Coordinates for ('Alamosa,', 'United States') fetched...
# Coordinates for ('Seoul,', 'South Korea') fetched...
# Coordinates for ('Kansas City,', 'United States') fetched...
# Coordinates for ('Baltimore,', 'United States') fetched...
# Coordinates for ('Reno,', 'United States') fetched...
# Coordinates for ('Vancouver,', 'United States') fetched...
# Coordinates for ('Chemnitz,', 'Germany') fetched...
# Coordinates for ('Hamburg,', 'Germany') fetched...
# Coordinates for ('Charlottesville,', 'United States') fetched...
# Coordinates for ('Kfar Saba,', 'Israel') fetched...
# Coordinates for ('Hangzhou,', 'China') fetched...
# Coordinates for ('Krakow,', 'Poland') fetched...
# Coordinates for ('Haifa,', 'Israel') fetched...
# Coordinates for ('London,', 'United States') fetched...
# Coordinates for ('Houston,', 'United States') fetched...
# Coordinates for ('Norfolk,', 'United States') fetched...
# Coordinates for ('Cluj-Napoca,', 'Romania') fetched...
# Coordinates for ('Las Vegas,', 'United States') fetched...
# Coordinates for ('Santiago,', 'Chile') fetched...
# Coordinates for ('Brisbane,', 'Australia') fetched...
# Coordinates for ('Ottawa,', 'Canada') fetched...
# Coordinates for ('Paris,', 'France') fetched...
# Coordinates for ('Berlin,', 'United States') fetched...
# Coordinates for ('Noida,', 'India') fetched...
# Coordinates for ('Riyadh,', 'Saudi Arabia') fetched...
# Coordinates for ('Wrocław,', 'Poland') fetched...
# Coordinates for ('Manila,', 'Philippines') fetched...
# Coordinates for ('Zug,', 'Switzerland') fetched...
# Coordinates for ('Cincinnati,', 'United States') fetched...
# Coordinates for ('Little Rock,', 'United States') fetched...
# Coordinates for ('Ann Arbor,', 'United States') fetched...
# Coordinates for ('Cleveland,', 'United States') fetched...
# Coordinates for ('Madrid,', 'Spain') fetched...
# Coordinates for ('Monterrey,', 'Mexico') fetched...
# Coordinates for ('Nashua,', 'United States') fetched...
# Coordinates for ('Vienna,', 'Austria') fetched...
# Coordinates for ('San Antonio,', 'United States') fetched...
# Coordinates for ('New Hope,', 'United States') fetched...
# Coordinates for ('Kyiv,', 'Ukraine') fetched...
# Coordinates for ('Geneva,', 'Switzerland') fetched...
# Coordinates for ('Chester,', 'United Kingdom') fetched...
# Coordinates for ('Warsaw,', 'Poland') fetched...
# Coordinates for ('Linz,', 'Austria') fetched...
# Coordinates for ('Boulder,', 'United States') fetched...
# Coordinates for ('Madison,', 'United States') fetched...
# Coordinates for ('Kitchener,', 'Canada') fetched...
# Coordinates for ('Tokyo,', 'Japan') fetched...
# Coordinates for ('Wellington,', 'New Zealand') fetched...
# Coordinates for ('Ibadan,', 'Nigeria') fetched...
# Coordinates for ('Gydnia,', 'Poland') fetched...
# Coordinates for ('Blumenau,', 'Brazil') fetched...
# Coordinates for ('Pune,', 'India') fetched...
# Coordinates for ('Zurich,', 'Switzerland') fetched...
# Coordinates for ('Baton Rouge,', 'United States') fetched...
# Coordinates for ('Orlando,', 'United States') fetched...
# Coordinates for ('Pittsburgh,', 'United States') fetched...
# Coordinates for ('Chennai,', 'United States') fetched...
# Coordinates for ('Shenzen,', 'China') fetched...
# Coordinates for ('Charleston,', 'United States') fetched...
# Coordinates for ('Albany,', 'United States') fetched...
# Coordinates for ('Milan,', 'Italy') fetched...
# Coordinates for ('Frankfurt,', 'Germany') fetched...
# Coordinates for ('Waterloo,', 'Canada') fetched...
# Coordinates for ('Karlsruhe,', 'Germany') fetched...
# Coordinates for ('Curitiba,', 'Brazil') fetched...
# Coordinates for ('New Haven,', 'United States') fetched...
# Coordinates for ('Coimbra,', 'Portugal') fetched...
# Coordinates for ('Walldorf,', 'Germany') fetched...
# Coordinates for ('Jersey City,', 'United States') fetched...
# Coordinates for ('Kiel,', 'Germany') fetched...
# Coordinates for ('Mexico City,', 'United States') fetched...
# Coordinates for ('Oxford,', 'United States') fetched...
# Coordinates for ('Wilmington,', 'United States') fetched...
# Coordinates for ('Providence,', 'United States') fetched...
# Coordinates for ('Bogota,', 'Colombia') fetched...
# Coordinates for ('Durham,', 'United States') fetched...
# Coordinates for ('Stockholm,', 'United States') fetched...
# Coordinates for ('Buenos Aires,', 'Argentina') fetched...
# Coordinates for ('Indore,', 'India') fetched...
# Coordinates for ('Patna,', 'India') fetched...
# Coordinates for ('Brisbane,', 'United States') fetched...
# Coordinates for ('Bismarck,', 'United States') fetched...
# Coordinates for ('Tokyo,', 'United States') fetched...
# Coordinates for ('Singapore,', 'United States') fetched...
# Coordinates for ('Grand Rapids,', 'United States') fetched...
# Coordinates for ('Shanghai,', 'China') fetched...
# Coordinates for ('Beau Vallon,', 'Seychelles') fetched...
# Coordinates for ('Beijing,', 'United States') fetched...
# Coordinates for ('Birmingham,', 'United States') fetched...
# Coordinates for ('Burlington,', 'United States') fetched...
# Coordinates for ('Bend,', 'United States') fetched...
# Coordinates for ('Guadalajara,', 'Mexico') fetched...
# Coordinates for ('Cairo,', 'Egypt') fetched...
# Coordinates for ('Dubai,', 'United States') fetched...
# Coordinates for ('Gothenburg,', 'Sweden') fetched...
# Coordinates for ('Dover,', 'United States') fetched...
# Coordinates for ('Malmö,', 'Sweden') fetched...
# Coordinates for ('Stamford,', 'United States') fetched...
# Coordinates for ('Logan,', 'United States') fetched...
# Coordinates for ('Eindhoven,', 'United States') fetched...
# Coordinates for ('Athens,', 'Greece') fetched...
# Coordinates for ('Hyderabad,', 'India') fetched...
# Coordinates for ('Nebraska City,', 'United States') fetched...
# Coordinates for ('Copenhagen,', 'United States') fetched...
# Coordinates for ('Non-U.S.,', 'Seychelles') fetched...
# Coordinates for ('Trondheim,', 'Norway') fetched...
# Coordinates for ('Oslo,', 'Sweden') fetched...
# Coordinates for ('Oslo,', 'Norway') fetched...
# Coordinates for ('Düsseldorf,', 'Germany') fetched...
# Coordinates for ('San Luis Obispo,', 'United States') fetched...
# Coordinates for ('Jerusalem,', 'Israel') fetched...
# Coordinates for ('Brussels,', 'Belgium') fetched...
# Coordinates for ('The Hague,', 'Netherlands') fetched...
# Coordinates for ('Copenhagen,', 'Denmark') fetched...
# Coordinates for ('Kuala Lumpur,', 'Malaysia') fetched...
# Coordinates for ('Bristol,', 'United Kingdom') fetched...
# Coordinates for ('Budapest,', 'Hungary') fetched...
# Coordinates for ('Ho Chi Minh City,', 'Vietnam') fetched...
# Coordinates for ('Winnipeg,', 'Canada') fetched...
# Coordinates for ('Bangkok,', 'Thailand') fetched...
# Coordinates for ('Vilnius,', 'Lithuania') fetched...
# Coordinates for ('Richmond,', 'United States') fetched...
# Coordinates for ('Melbourne,', 'United States') fetched...
# Coordinates for ('Saskatoon,', 'Canada') fetched...
# Coordinates for ('Porto Alegre,', 'Brazil') fetched...
# Coordinates for ('New Delhi,', 'United States') fetched...
# Coordinates for ('Victoria,', 'Seychelles') fetched...
# Coordinates for ('Sydney,', 'United States') fetched...
# Coordinates for ('Ferdericton,', 'Canada') fetched...
# City coorodinates not found. Skipping...
# Coordinates for ('Dakar,', 'Senegal') fetched...
# Coordinates for ('Florianópolis,', 'Brazil') fetched...
# Coordinates for ('Lahore,', 'Pakistan') fetched...
# Coordinates for ('Louisville,', 'United States') fetched...
# Coordinates for ('Huntsville,', 'United States') fetched...
# Coordinates for ('Dubai,', 'United Arab Emirates') fetched...
# Coordinates for ('SF Bay Area,', 'Israel') fetched...
# Coordinates for ('Spokane,', 'United States') fetched...
# Coordinates for ('Lima,', 'Peru') fetched...
# Coordinates for ('Malmo,', 'Sweden') fetched...
# Coordinates for ('Brasilia,', 'Brazil') fetched...
# Coordinates for ('Selangor,', 'United States') fetched...
# Coordinates for ('Manama,', 'Bahrain') fetched...
# Coordinates for ('Karachi,', 'Pakistan') fetched...
# Coordinates for ('Bucharest,', 'Romania') fetched...
# Coordinates for ('Istanbul,', 'Turkey') fetched...
# Coordinates for ('Sao Paulo,', 'United States') fetched...
# Coordinates for ('Moscow,', 'Russia') fetched...
# Coordinates for ('Davenport,', 'United States') fetched...
# Coordinates for ('Toulouse,', 'France') fetched...
# Coordinates for ('Non-U.S.,', 'China') fetched...
# Coordinates for ('Toronto,', 'United States') fetched...
# Coordinates for ('Montevideo,', 'Uruguay') fetched...
# Coordinates for ('Fayetteville,', 'United States') fetched...
# Coordinates for ('Sofia,', 'Bulgaria') fetched...
# Coordinates for ('Santa Fe,', 'United States') fetched...
# Coordinates for ('Cork,', 'Ireland') fetched...
# Coordinates for ('Ahmedabad,', 'India') fetched...
# Coordinates for ('Joinville,', 'Brazil') fetched...
# Coordinates for ('Hanoi,', 'Vietnam') fetched...
# Coordinates for ('Norwalk,', 'United States') fetched...
# Coordinates for ('Dusseldorf,', 'Germany') fetched...
# Coordinates for ('Lisbon,', 'Portugal') fetched...
# Coordinates for ('Cape Town,', 'South Africa') fetched...
# Coordinates for ('Missoula,', 'United States') fetched...
# Coordinates for ('Quebec,', 'Canada') fetched...
# Coordinates for ('Prague,', 'Czech Republic') fetched...
# Coordinates for ('Yangon,', 'Myanmar') fetched...
# Coordinates for ('New Orleans,', 'United States') fetched...
#       company       location    industry  total_laid_off        date  \
# 0    Airtable    SF Bay Area     Product             237  2023-09-14
# 1          R3  New York City      Crypto               1  2023-09-14
# 2  Akili Labs         Boston  Healthcare               1  2023-09-13
# 3      Google    SF Bay Area    Consumer               1  2023-09-13
# 4      Evolve         Denver      Travel             175  2023-09-12
#
#       stage        country        Lat         Lon
# 0  Series F  United States  37.788497 -122.355847
# 1  Series A  United States  40.737233  -73.862477
# 2  Post-IPO  United States  42.350804  -71.053673
# 3  Post-IPO  United States  37.788497 -122.355847
# 4  Series F  United States  39.748625 -104.988623

# %%
layoffs_unsanitized_dataset
# Out:
#             company        location        industry  total_laid_off  \
# 0          Airtable     SF Bay Area         Product             237
# 1                R3   New York City          Crypto               1
# 2        Akili Labs          Boston      Healthcare               1
# 3            Google     SF Bay Area        Consumer               1
# 4            Evolve          Denver          Travel             175
# ...             ...             ...             ...             ...
# 3017        Service     Los Angeles          Travel               1
# 3018   HopSkipDrive     Los Angeles  Transportation               8
# 3019    Panda Squad     SF Bay Area        Consumer               6
# 3020  Tamara Mellon     Los Angeles          Retail              20
# 3021       EasyPost  Salt Lake City       Logistics              75
#
#            date     stage        country        Lat         Lon
# 0    2023-09-14  Series F  United States  37.788497 -122.355847
# 1    2023-09-14  Series A  United States  40.737233  -73.862477
# 2    2023-09-13  Post-IPO  United States  42.350804  -71.053673
# 3    2023-09-13  Post-IPO  United States  37.788497 -122.355847
# 4    2023-09-12  Series F  United States  39.748625 -104.988623
# ...         ...       ...            ...        ...         ...
# 3017 2020-03-16      Seed  United States   25.60289  -108.48095
# 3018 2020-03-13   Unknown  United States   25.60289  -108.48095
# 3019 2020-03-13      Seed  United States  37.788497 -122.355847
# 3020 2020-03-12  Series C  United States   25.60289  -108.48095
# 3021 2020-03-11  Series A  United States   40.76127 -111.891678
#
# [3022 rows x 9 columns]

# %%
# Store the sanitized data in a csv to use for data analysis and graph plot
layoffs_unsanitized_dataset.to_csv("Output_Data/Layoffs_Sanitized.csv", index=False)

# %% [markdown]
# ####  I will use this clean dataset to find answers to the questions from this dataset. Please refer to "Layoffs_Dataset_Analysis.ipynb" notebook for the next part of the project
